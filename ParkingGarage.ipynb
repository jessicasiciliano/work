# %%
print('Parking Rate by Hours Listed Below:')

for hours in range(1, 9, 1):
  cost = hours * 2.5 + 5
  if cost >= 20:
    cost = 20
  elif cost <= 10:
    cost = 10
  else:
    cost
  print(hours, cost)
# Out:
# Parking Rate by Hours Listed Below:
# 1 10
# 2 10
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20
# 7 20
# 8 20
